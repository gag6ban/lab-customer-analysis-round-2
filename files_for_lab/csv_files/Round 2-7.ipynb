# %% [markdown]
# # Round 2

# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')
file1.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
cols = []
for column in file1.columns:
    cols.append(column.lower())
file1.columns = cols
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file1.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
file1.isna().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
file1.drop_duplicates(inplace = True)
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
file1 = file1.drop(['vehicle type' ], axis =1)
column_names = file1.columns
column_names
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size'],
#       dtype='object')

# %%
file1.isna().sum()
# Out:
# unnamed: 0                         0
# customer                           0
# state                            631
# customer lifetime value            0
# response                         631
# coverage                           0
# education                          0
# effective to date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim          633
# months since policy inception      0
# number of open complaints        633
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                    622
# vehicle size                     622
# dtype: int64

# %%
# command to drop all NaN values
file1 = file1.dropna()
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective to date employmentstatus  \
# ...

# %%
file1.isna().sum() #to check if all NaN values are deleted
# Out:
# unnamed: 0                       0
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# dtype: int64

# %%
# class pandas.DatetimeIndex(data=None, freq=NoDefault.no_default, tz=None, normalize=False, closed=None, ambiguous='raise', dayfirst=False, yearfirst=False, dtype=None, copy=False, name=None)
# pd.DatetimeIndex(file1['effective to date']).month
pd.DatetimeIndex(file1['effective to date']).month
# Out:
# Int64Index([2, 1, 2, 1, 2, 2, 1, 1, 1, 1,
#             ...
#             1, 2, 2, 1, 1, 1, 2, 1, 2, 2],
#            dtype='int64', name='effective to date', length=9134)

# %%
file1 ['month'] = pd.DatetimeIndex(file1['effective to date']).month #adding column and extracting the number which indicates the month
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective to date employmentstatus  \
# ...

# %% [markdown]
# # Round 3

# %%
file1 # to show dataframe
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective to date employmentstatus  \
# ...

# %%
file1.describe() # describes numerical data in column
# Out:
#          unnamed: 0  customer lifetime value        income  \
# count   9134.000000              9134.000000   9134.000000
# mean    5490.357675              8004.940475  37657.380009
# std     3148.183236              6870.967608  30379.904734
# min        0.000000              1898.007675      0.000000
# 25%     2764.250000              3994.251794      0.000000
# 50%     5508.500000              5780.182197  33889.500000
# 75%     8218.750000              8962.167041  62320.000000
# max    10908.000000             83325.381190  99981.000000
#
#        monthly premium auto  months since last claim  \
# count           9134.000000              9134.000000
# mean              93.219291                15.097000
# std               34.407967                10.073257
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
file1.describe().T # transpose all
# Out:
#                                 count          mean           std  \
# unnamed: 0                     9134.0   5490.357675   3148.183236
# customer lifetime value        9134.0   8004.940475   6870.967608
# income                         9134.0  37657.380009  30379.904734
# monthly premium auto           9134.0     93.219291     34.407967
# months since last claim        9134.0     15.097000     10.073257
# months since policy inception  9134.0     48.064594     27.905991
# number of open complaints      9134.0      0.384388      0.910384
# number of policies             9134.0      2.966170      2.390182
# total claim amount             9134.0    434.088794    290.500092
# month                          9134.0      1.463762      0.498712
#
#                                        min          25%           50%  \
# unnamed: 0                        0.000000  2764.250000   5508.500000
# customer lifetime value        1898.007675  3994.251794   5780.182197
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
sns.countplot("response", data=file1)
# Out:
# C:\Users\gau82\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='response', ylabel='count'>

# %%
file1['response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: response, dtype: int64

# %%
sc =file1['sales channel'].value_counts()
sc
# Out:
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: sales channel, dtype: int64

# %%
# plotting a bar chart
sns.countplot(x= 'response', hue= 'sales channel', data=file1)
plt.show()

# %%
# rounding off to next 2 decimal
summary = file1.describe().T
def roundforme(x):
    return round(x,2)

# # summary
for col in summary.columns:
    summary[col] = summary[col].apply(roundforme)
summary
# Out:
#                                 count      mean       std      min      25%  \
# unnamed: 0                     9134.0   5490.36   3148.18     0.00  2764.25
# customer lifetime value        9134.0   8004.94   6870.97  1898.01  3994.25
# income                         9134.0  37657.38  30379.90     0.00     0.00
# monthly premium auto           9134.0     93.22     34.41    61.00    68.00
# months since last claim        9134.0     15.10     10.07     0.00     6.00
# months since policy inception  9134.0     48.06     27.91     0.00    24.00
# number of open complaints      9134.0      0.38      0.91     0.00     0.00
# number of policies             9134.0      2.97      2.39     1.00     1.00
# total claim amount             9134.0    434.09    290.50     0.10   272.26
# month                          9134.0      1.46      0.50     1.00     1.00
#
#                                     50%       75%       max
# unnamed: 0                      5508.50   8218.75  10908.00
# ...

# %%
# plotting a bar chart
sns.displot(data=file1, x="total claim amount", hue="response")
plt.show()

# giving error unable to plot

# %%
sns.boxplot(data=file1, x="total claim amount", hue="response")
# Out:
# <AxesSubplot:xlabel='total claim amount'>

# %%
# plotting a bar chart
sns.displot(data=file1, x="income", hue="response")
plt.show()

#interrepted the kernel. took long time to process

# %%
sns.boxplot(data=file1, x="income", hue="response")
plt.show()
